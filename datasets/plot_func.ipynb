3.64875257, 20.56417048, 18.8182485, -0.38214175, -0.76907966, 1.89034964, -0.30191893, 0.02027567, 5.6690344, 0.28744564, 8.11979047, -0.79058849, 5.75729647, 0.69477941, 4.05657317, 25.18815246, 4.70030929, -0.50700656, 5.37183715, -0.56461058, -7.7694105, 3.19210676, 9.72783506, 3.40598447, 2.90589615, -0.48406432, 11.08451887, 21.52256041, -8.9553879, -7.28817456, -5.42679598, 2.06668775, 4.51566847, -13.97329342, -8.20569488, -0.15962233, 16.41632122, -4.58822057, 0.33520774, 0.11478422, 0.72315794, 3.66590596, -0.70075956, 5.02725808, 5.15597053, 11.56707159, 8.37258618, -0.33168051, 2.74239419, 0.40983056, -5.22587342, -11.55489432, -0.41465856, -7.20100274, 8.5313717, 2.25227758, 1.03377682, 1.47739889, 0.08072371, 0.91682471, -27.34668246, -0.62575453, -0.42710539, 11.58129341, -0.67226542, 0.12599184, 15.17700112, 1.72390183, 3.11426713, 13.61596301, 4.9297043, -0.68169117, -6.60779585, -0.69319284, 0.28283365, -0.80320622, 3.57953421, -6.92713929, -0.68443921, -9.06701182, 1.10306627, -0.42276937, -11.70450191, 10.15918579, 1.93116198, -12.52189068, -0.7739733, 0.27185257, 4.62121786, 9.67178372, 3.66817146, -0.73806652, 0.25149656, 6.93075123, -6.0997772, -0.53354123, 3.80742426, 4.30594204, 0.14850379, -3.6672738, 21.85079221, 4.83631431, -0.27325187, -0.77140617, 0.18030768, -4.71415162, -0.10247968, -0.57798151, -6.67855556, -0.62354589, -0.38495782, 8.77186414, -0.70231184, 10.01417932, 18.22664145, 5.5235774, 11.90525289, 0.32993838, -0.02685162, 9.39184788, 3.53366921, 18.24933702, 3.19699769, -0.33867547, 11.73886956, 0.10116185, -23.40545207, 10.33027163, 2.0878288, 1.58470451, 2.82634214, -0.78450128, 0.78993175, 7.70549908, -4.78381686, 6.84489714, 0.07646683, 0.10395785, 22.65323123, 1.32610071, -0.50696324, -0.47443422, 5.97063044, -0.60189226, 5.22880181, 2.39854868, 0.07604872, 2.71434833, -0.94926131], "EQ": "-0.418067661427745*sin(-0.8017857769294869*exp(1.3780539007806185*x2))/0.013778639043966034*cos(1.4380041111085564*sin(0.328960475394942*x1+-1.8703605942604717))+-0.883225300143172", "Skeleton": "C*sin(C*exp(C*x2))/C*cos(C*sin(C*x1+C))+C"}
eval_dict_x1= []
eval_dict_x2 = []

for x_s in eval_dict["X"]:
    eval_dict_x1.append(x_s[0])
    eval_dict_x2.append(x_s[1])

# %%
eval_dict_x1 = np.array(eval_dict_x1)
eval_dict_x2 = np.array(eval_dict_x2)

# %%
function_str2 = '2.747368052130705*log(316.86121173438244*x1**2+614.4495683415953*x1+519.3647156697168)/114.16817113716905*cos(2.7752725050618356*x1**2+-1.000385818142951*x1+1.7928136414871485)+0.09549900062269225+(1.2985341969555297*sin(1.1364741808168295*x2**2+1.6023921417682174*x2**2/(1.0325061080504172*x2)+1.2232900894760403/(0.840941560447651*x2))-0.7486906573335217)'
print(function_str2)
# Out:
# 2.747368052130705*log(316.86121173438244*x1**2+614.4495683415953*x1+519.3647156697168)/114.16817113716905*cos(2.7752725050618356*x1**2+-1.000385818142951*x1+1.7928136414871485)+0.09549900062269225+(1.2985341969555297*sin(1.1364741808168295*x2**2+1.6023921417682174*x2**2/(1.0325061080504172*x2)+1.2232900894760403/(0.840941560447651*x2))-0.7486906573335217)

# %%
# Define the function as a string
function_str = '-0.418067661427745*sin(-0.8017857769294869*exp(1.3780539007806185*x2))/0.013778639043966034*cos(1.4380041111085564*sin(0.328960475394942*x1+-1.8703605942604717))+-0.883225300143172'
function_str2 = '2.747368052130705*log(316.86121173438244*x1**2+614.4495683415953*x1+519.3647156697168)/114.16817113716905*cos(2.7752725050618356*x1**2+-1.000385818142951*x1+1.7928136414871485)+0.09549900062269225+(1.2985341969555297*sin(1.1364741808168295*x2**2+1.6023921417682174*x2**2/(1.0325061080504172*x2)+1.2232900894760403/(0.840941560447651*x2))-0.7486906573335217)'
# Define the variables
x1, x2 = sp.symbols('x1 x2')

# Convert the string to a symbolic expression
symbolic_function = sp.sympify(function_str)
symbolic_function2 = sp.sympify(function_str2)

# Convert the symbolic expression to numerical functions
numerical_function_x1 = sp.lambdify((x1, x2), symbolic_function, "numpy")
numerical_function_x2 = sp.lambdify((x1, x2), symbolic_function2, "numpy")
# Generate the range of values for x1 and x2
x_values = np.linspace(-3.0, 3.0, 500)

# Evaluate the function for x2 held constant and x1 varying
x2_constant = 0.0000001  # Example constant value for x2
y_values_x1_constant = numerical_function_x1(x_values, x2_constant)
y_values_x1_constant_2 = numerical_function_x2(x_values, x2_constant)



# Evaluate the function for x1 held constant and x2 varying
x1_constant = 0.0000001 # Example constant value for x1
y_values_x2_constant = numerical_function_x1(x1_constant, x_values)
y_values_x2_constant_2 = numerical_function_x2(x1_constant, x_values)

print(len(y_values_x2_constant))
print(y_values_x2_constant_2)
# Plot the functions
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(x_values, y_values_x1_constant, label = "SymbolicGPT", color='b')
plt.plot(x_values, y_values_x1_constant_2,  label = "GAM SymbolicGPT",color='r', linestyle='dashed')
plt.title("Two-Variables with x2 constant")

plt.xlabel("x1")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(x_values, y_values_x2_constant, label = "SymbolicGPT",color='b')
plt.plot(x_values, y_values_x2_constant_2,  label = "GAM SymbolicGPT", color='r', linestyle='dashed' )
plt.title("Two-Variables with x1 constant")
plt.xlabel("x2")

plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 500
# [-1.89454519 -1.92294547 -1.94600558 -1.96370458 -1.97604557 -1.98305488
#  -1.98478123 -1.98129475 -1.97268599 -1.95906485 -1.94055943 -1.9173149
#  -1.88949228 -1.85726721 -1.82082872 -1.78037796 -1.73612693 -1.68829725
#  -1.63711887 -1.58282885 -1.52567014 -1.46589036 -1.40374066 -1.33947458
#  -1.27334695 -1.20561281 -1.13652643 -1.06634031 -0.99530429 -0.92366466
#  -0.85166335 -0.77953717 -0.70751707 -0.63582754 -0.56468594 -0.49430203
#  -0.4248774  -0.3566051  -0.2896692  -0.22424451 -0.16049626 -0.09857987
#  -0.0386408   0.01918563  0.07477427  0.12801028  0.17878905  0.2270162
#   0.27260754  0.31548892  0.35559613  0.39287471  0.42727977  0.45877578
#   0.48733628  0.5129437   0.53558898  0.55527133  0.57199792  0.58578349
#   0.59665008  0.60462665  0.60974869  0.61205794  0.61160194  0.6084337
#   0.60261135  0.59419773  0.58326003  0.56986946  0.55410086  0.53603234
#   0.51574497  0.4933224   0.46885053  0.44241724  0.41411198  0.38402557
# ...
